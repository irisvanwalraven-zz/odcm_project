# %% [markdown]
# # <span style="color:blue">Scraping data from Coolblue</span>
# ![image.png](attachment:image.png)

# %% [markdown]
# For the course Online Data Collection & Management at Tilburg University, our team aims to scrape from the Coolblue website. Coolblue is a Dutch e-commerce company. However, Coolblue claims that they are more than just an ecommerce company: she build end-to-end  solution for her customers. They are active in The Netherlands, Belgium, and Germany, both online and in her 15 physical stores.
#
# In this scrape we scrape Coolblue’s supply in laptops. All laptops Coolblue has (in this code referred to as "al") are compared to Coolblue’s Choice laptops (in this code referred to as "cc") regarding the names, prices, and urls of these laptops.
#
# Coolblue’s Choice indicates the best products for Coolblue’s customers, according to experts and other consumers. The products in this category are hardly ever returned, and have the best reviews. It is unique and very customer-oriented. It makes the choice to buy a certain product easier and more accessible.
#
# In this notebook we will discuss the scraping in three chapters:
# 1. The preparation before scraping
# 2. The Coolblues Choice and All Laptops scraper
# 3. Saving the scraped data in csv files

# %% [markdown]
# # <span style="color:blue">1. The preparation before scraping</span>
# Before the Coolblue website can be scraped, a few things need to be prepared:
# * Import necessary libraries
# * Set driver and define the base url
# * Accept cookies

# %% [markdown]
# ### 1.1 Import necessary libraries

# %%
import requests # Lets us make HTML request to Coolblue's website server for retrieving the data from their page
from bs4 import BeautifulSoup # Easy to use for beginners and will allow us to extract data from HTML files
import time # Pauses the execution of the commands. We use this because of the amount of data we gather
from time import sleep # Sleep package is needed to obey retrieval limits
import csv # Stores the scraped data in a csv file in the end
from datetime import datetime # Adds current day to csv file

import selenium # To open selenium webdriver to gather information from the websites
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from re import search
from selenium.webdriver import ActionChains

# %% [markdown]
# ### 1.2 Set driver and define the base url

# %%
# Automatically installs/updates and opens ChromeDriver
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 100.0.4896
# Get LATEST chromedriver version for 100.0.4896 google-chrome
# Driver [/Users/irisvanwalraven/.wdm/drivers/chromedriver/mac64/100.0.4896.60/chromedriver] found in cache

# %%
# Defining the base url
base_url = 'https://www.coolblue.nl'
driver.get(base_url)
sleep(2) # To load the full page

# %% [markdown]
# ### 1.3 Accept cookies

# %%
driver.find_element_by_name("accept_cookie").click()
print("ok")
# Out:
# ok

# %% [markdown]
# # <span style="color:blue">2. The Coolblues Choice and All Laptops scraper</span>

# %% [markdown]
# ### 2.1 Coolblues Choice
# In this step the page urls are defined

# %%
def generate_page_urls_cc(base_url, num_pages):
    page_urls_cc = []
    
    for counter in range(1,num_pages +1):
        coolblues_choice_urls = base_url + '/en/laptops/coolblues-choice?page=' + str(counter)
        page_urls_cc.append(coolblues_choice_urls)
    return page_urls_cc

# %%
page_urls_cc = generate_page_urls_cc(base_url, 2) # Coolblues Choice only has 2 pages, so we define 2 page urls
page_urls_cc
# Out:
# ['https://www.coolblue.nl/en/laptops/coolblues-choice?page=1',
#  'https://www.coolblue.nl/en/laptops/coolblues-choice?page=2']

# %% [markdown]
# In the next step, an information list is defined where the following information is collected per laptop: titles, urls and prices.

# %%
def extract_laptop_urls_cc(page_urls_cc):
    information_list_cc = []
    
    for page_url_cc in page_urls_cc: 
        driver.get(page_url_cc) # To gather information from the predefined page urls
        time.sleep(2)
        res_cc = driver.page_source.encode('utf-8')
        soup_cc = BeautifulSoup(res_cc, "html.parser")
        information_cc = soup_cc.find_all(class_="product-grid__card")
        
        # For each laptop on that page look up the title, url and price and store it in a list
        for info_cc in information_cc: 
            title_cc = info_cc.find("img").attrs["alt"].replace(" Buy a laptop?","")
            url_cc = "https://www.coolblue.nl" + info_cc.find("a").attrs["href"]
            price_cc = info_cc.find(class_="sales-price__current js-sales-price-current").text
            information_list_cc.append({"title": title_cc,
                                        "url": url_cc,
                                        "price": price_cc}) 
        
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);') # Scroll down the page to collect data from all laptops
            
        sleep(1)  # Pause 1 second after each request
            
    return information_list_cc

# %%
information_list_cc = extract_laptop_urls_cc(page_urls_cc) # To create the list with information per laptop
information_list_cc
# Out:
# [{'title': 'HP 15s-fq2960nd',
#   'url': 'https://www.coolblue.nl/en/product/873236/hp-15s-fq2960nd.html',
#   'price': '499,-'},
#  {'title': 'Lenovo ThinkBook 15 G2 - 20VE0049MH',
#   'url': 'https://www.coolblue.nl/en/product/872868/lenovo-thinkbook-15-g2-20ve0049mh.html',
#   'price': '1.059,-'},
#  {'title': 'Apple MacBook Air (2020) 16GB/256GB Apple M1 with 7-core GPU Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/874171/apple-macbook-air-2020-16gb-256gb-apple-m1-with-7-core-gpu-space-gray.html',
#   'price': '1.359,-'},
#  {'title': 'HP Pavilion 15-eh1907nd',
#   'url': 'https://www.coolblue.nl/en/product/889428/hp-pavilion-15-eh1907nd.html',
#   'price': '599,-'},
#  {'title': 'Lenovo IdeaPad 5 14ARE05 81YM00F7MH',
#   'url': 'https://www.coolblue.nl/en/product/900571/lenovo-ideapad-5-14are05-81ym00f7mh.html',
#   'price': '749,-'},
#  {'title': 'HP Chromebook 14a-na0170nd',
#   'url': 'https://www.coolblue.nl/en/product/868651/hp-chromebook-14a-na0170nd.html',
#   'price': '249,-'},
#  {'title': 'Lenovo ThinkBook 15 G2 - 20VE0046MH',
#   'url': 'https://www.coolblue.nl/en/product/872864/lenovo-thinkbook-15-g2-20ve0046mh.html',
#   'price': '799,-'},
#  {'title': 'Apple MacBook Pro 13 inches (2020) 16GB/256GB Apple M1 Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/874177/apple-macbook-pro-13-inches-2020-16gb-256gb-apple-m1-space-gray.html',
#   'price': '1.609,-'},
#  {'title': 'Apple MacBook Pro 13 inches (2020) 16GB/512GB Apple M1 Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/874178/apple-macbook-pro-13-inches-2020-16gb-512gb-apple-m1-space-gray.html',
#   'price': '1.769,-'},
#  {'title': 'Lenovo IdeaPad 5 Pro 14ACN6 82L7006VMH',
#   'url': 'https://www.coolblue.nl/en/product/878296/lenovo-ideapad-5-pro-14acn6-82l7006vmh.html',
#   'price': '999,-'},
#  {'title': 'Acer Swift 3 SF316-51-51BS',
#   'url': 'https://www.coolblue.nl/en/product/879388/acer-swift-3-sf316-51-51bs.html',
#   'price': '769,-'},
#  {'title': 'Asus Chromebook C523NA-EJ0446',
#   'url': 'https://www.coolblue.nl/en/product/886177/asus-chromebook-c523na-ej0446.html',
#   'price': '299,-'},
#  {'title': 'Acer Chromebook Spin 311 CP311-2H-C3DE',
#   'url': 'https://www.coolblue.nl/en/product/853049/acer-chromebook-spin-311-cp311-2h-c3de.html',
#   'price': '249,-'},
#  {'title': 'MSI Modern 15 A11M-814NL',
#   'url': 'https://www.coolblue.nl/en/product/892840/msi-modern-15-a11m-814nl.html',
#   'price': '799,-'},
#  {'title': 'Acer Swift 3 SF314-43-R13Q',
#   'url': 'https://www.coolblue.nl/en/product/882455/acer-swift-3-sf314-43-r13q.html',
#   'price': '579,-'},
#  {'title': 'HP ProBook 450 G8 - 203F7EA',
#   'url': 'https://www.coolblue.nl/en/product/872309/hp-probook-450-g8-203f7ea.html',
#   'price': '1.149,-'},
#  {'title': 'Apple MacBook Pro 14 inches (2021) M1 Pro (8-core CPU/14-core GPU) 16GB/1TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894397/apple-macbook-pro-14-inches-2021-m1-pro-8-core-cpu-14-core-gpu-16gb-1tb-space-gray.html',
#   'price': '2.329,-'},
#  {'title': 'Lenovo Legion 5 17IMH05 82B300CBMH',
#   'url': 'https://www.coolblue.nl/en/product/882865/lenovo-legion-5-17imh05-82b300cbmh.html',
#   'price': '1.199,-'},
#  {'title': 'Apple MacBook Pro 14 inches (2021) M1 Pro (8-core CPU/14-core GPU) 32GB/1TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894399/apple-macbook-pro-14-inches-2021-m1-pro-8-core-cpu-14-core-gpu-32gb-1tb-space-gray.html',
#   'price': '2.879,-'},
#  {'title': 'Lenovo Legion 5 17ITH6H 82JM001EMH',
#   'url': 'https://www.coolblue.nl/en/product/882868/lenovo-legion-5-17ith6h-82jm001emh.html',
#   'price': '1.499,-'},
#  {'title': 'Acer Chromebook Spin 514 CP514-1HH-R7PK',
#   'url': 'https://www.coolblue.nl/en/product/876297/acer-chromebook-spin-514-cp514-1hh-r7pk.html',
#   'price': '649,-'},
#  {'title': 'HP 470 G8 i7-16gb-512GB',
#   'url': 'https://www.coolblue.nl/en/product/889652/hp-470-g8-i7-16gb-512gb.html',
#   'price': '1.349,-'},
#  {'title': 'Acer Chromebook Spin 513 CP513-1H-S2LW',
#   'url': 'https://www.coolblue.nl/en/product/872378/acer-chromebook-spin-513-cp513-1h-s2lw.html',
#   'price': '299,-'},
#  {'title': 'Microsoft Surface Pro 8 - i5/16/256 (Graphite)',
#   'url': 'https://www.coolblue.nl/en/product/897655/microsoft-surface-pro-8-i5-16-256-graphite.html',
#   'price': '1.249,-'},
#  {'title': 'HP ProBook 440 G8 - 203F0EA',
#   'url': 'https://www.coolblue.nl/en/product/872297/hp-probook-440-g8-203f0ea.html',
#   'price': '999,-'},
#  {'title': 'Lenovo IdeaPad Gaming 3 15ACH6 82K200ANMH',
#   'url': 'https://www.coolblue.nl/en/product/879991/lenovo-ideapad-gaming-3-15ach6-82k200anmh.html',
#   'price': '799,-'},
#  {'title': 'Acer Chromebook 314 CB314-1HT-C6XM',
#   'url': 'https://www.coolblue.nl/en/product/839397/acer-chromebook-314-cb314-1ht-c6xm.html',
#   'price': '349,-'},
#  {'title': 'HP Pavilion x360 14-dy0902nd',
#   'url': 'https://www.coolblue.nl/en/product/877670/hp-pavilion-x360-14-dy0902nd.html',
#   'price': '719,-'},
#  {'title': 'HP Pavilion x360 14-dy0900nd',
#   'url': 'https://www.coolblue.nl/en/product/877668/hp-pavilion-x360-14-dy0900nd.html',
#   'price': '549,-'},
#  {'title': 'Apple MacBook Pro 14 inches (2021) M1 Pro (10-core CPU/16-core GPU) 32GB/512GB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894402/apple-macbook-pro-14-inches-2021-m1-pro-10-core-cpu-16-core-gpu-32gb-512gb-space-gray.html',
#   'price': '2.919,-'},
#  {'title': 'Acer Aspire Vero AV15-51-574G',
#   'url': 'https://www.coolblue.nl/en/product/892461/acer-aspire-vero-av15-51-574g.html',
#   'price': '799,-'},
#  {'title': 'Apple MacBook Pro 16 inches (2021) M1 Max (10-core CPU/24-core GPU) 32GB/2TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894447/apple-macbook-pro-16-inches-2021-m1-max-10-core-cpu-24-core-gpu-32gb-2tb-space-gray.html',
#   'price': '4.129,-'},
#  {'title': 'MSI Summit E16 Flip Evo A11MT-037NL',
#   'url': 'https://www.coolblue.nl/en/product/886479/msi-summit-e16-flip-evo-a11mt-037nl.html',
#   'price': '1.349,-'},
#  {'title': 'Asus ZenBook Flip S 13 UX371EA-HL135T',
#   'url': 'https://www.coolblue.nl/en/product/874303/asus-zenbook-flip-s-13-ux371ea-hl135t.html',
#   'price': '1.299,-'},
#  {'title': 'Apple MacBook Pro 16 inches (2021) M1 Pro (10-core CPU/16-core GPU) 16GB/2TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894442/apple-macbook-pro-16-inches-2021-m1-pro-10-core-cpu-16-core-gpu-16gb-2tb-space-gray.html',
#   'price': '3.119,-'},
#  {'title': 'HP VICTUS 16-e0306nd',
#   'url': 'https://www.coolblue.nl/en/product/897735/hp-victus-16-e0306nd.html',
#   'price': '999,-'},
#  {'title': 'Lenovo Chromebook IdeaPad Flex 5 13IML05 82B8000SMH',
#   'url': 'https://www.coolblue.nl/en/product/860582/lenovo-chromebook-ideapad-flex-5-13iml05-82b8000smh.html',
#   'price': '479,-'},
#  {'title': 'HP EliteBook 850 G8 - 2Y2S4EA',
#   'url': 'https://www.coolblue.nl/en/product/889655/hp-elitebook-850-g8-2y2s4ea.html',
#   'price': '1.699,-'},
#  {'title': 'Asus Chromebook C434TA-AI0485',
#   'url': 'https://www.coolblue.nl/en/product/886176/asus-chromebook-c434ta-ai0485.html',
#   'price': '619,-'},
#  {'title': 'Lenovo Legion 5 Pro 16ITH6H 82JD00AQMH',
#   'url': 'https://www.coolblue.nl/en/product/900578/lenovo-legion-5-pro-16ith6h-82jd00aqmh.html',
#   'price': '2.099,-'},
#  {'title': 'HP Chromebook x360 14c-ca0000nd',
#   'url': 'https://www.coolblue.nl/en/product/864176/hp-chromebook-x360-14c-ca0000nd.html',
#   'price': '529,-'},
#  {'title': 'MSI Raider GE66 Deluxe Edition 12UH-472NL',
#   'url': 'https://www.coolblue.nl/en/product/899580/msi-raider-ge66-deluxe-edition-12uh-472nl.html',
#   'price': '3.549,-'},
#  {'title': 'Lenovo ThinkPad P17 G2 - 20YU000BMH',
#   'url': 'https://www.coolblue.nl/en/product/889614/lenovo-thinkpad-p17-g2-20yu000bmh.html',
#   'price': '3.399,-'}]

# %%
print("The number of laptops in Coolblues choice is " +str(len(information_list_cc)))
# Out:
# The number of laptops in Coolblues choice is 43

# %% [markdown]
# ### 2.1 All Laptops
# In this step the page urls are defined

# %%
def generate_page_urls_al(base_url, num_pages):
    page_urls_al = []
    
    for counter in range(1,num_pages +1):
        all_laptops_urls = base_url + '/en/laptops/filter?page=' + str(counter)
        page_urls_al.append(all_laptops_urls)
    return page_urls_al

# %%
page_urls_al = generate_page_urls_al(base_url, 20) # All Laptops has 20 pages, so we define 20 page urls
page_urls_al
# Out:
# ['https://www.coolblue.nl/en/laptops/filter?page=1',
#  'https://www.coolblue.nl/en/laptops/filter?page=2',
#  'https://www.coolblue.nl/en/laptops/filter?page=3',
#  'https://www.coolblue.nl/en/laptops/filter?page=4',
#  'https://www.coolblue.nl/en/laptops/filter?page=5',
#  'https://www.coolblue.nl/en/laptops/filter?page=6',
#  'https://www.coolblue.nl/en/laptops/filter?page=7',
#  'https://www.coolblue.nl/en/laptops/filter?page=8',
#  'https://www.coolblue.nl/en/laptops/filter?page=9',
#  'https://www.coolblue.nl/en/laptops/filter?page=10',
#  'https://www.coolblue.nl/en/laptops/filter?page=11',
#  'https://www.coolblue.nl/en/laptops/filter?page=12',
#  'https://www.coolblue.nl/en/laptops/filter?page=13',
#  'https://www.coolblue.nl/en/laptops/filter?page=14',
#  'https://www.coolblue.nl/en/laptops/filter?page=15',
#  'https://www.coolblue.nl/en/laptops/filter?page=16',
#  'https://www.coolblue.nl/en/laptops/filter?page=17',
#  'https://www.coolblue.nl/en/laptops/filter?page=18',
#  'https://www.coolblue.nl/en/laptops/filter?page=19',
#  'https://www.coolblue.nl/en/laptops/filter?page=20']

# %% [markdown]
# In the next step, an information list is defined where the following information is collected per laptop: titles, urls and prices.

# %%
def extract_laptop_urls_al(page_urls_al):
    information_list_al = []
    
    for page_url_al in page_urls_al:
            driver.get(page_url_al) # To gather information from the predefined page urls
            time.sleep(2)
            res_al = driver.page_source.encode('utf-8')
            soup_al = BeautifulSoup(res_al, "html.parser")
            information_al = soup_al.find_all(class_="product-grid__card")
        
        # For each laptop on that page look up the title, url and price and store it in a list
            for info_al in information_al:
                title_al = info_al.find("img").attrs["alt"].replace(" Buy a laptop?","")
                url_al = "https://www.coolblue.nl" + info_al.find("a").attrs["href"]
                if 
                price_al = info_al.find(class_="sales-price__current js-sales-price-current") # We want to get the price with code: '.text' but it gives an error so we use the whole html line
                information_list_al.append({"title": title_al,
                                            "url": url_al,
                                            "price": price_al}) 
                
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);') # Scroll down the page to collect data from all laptops
        
            sleep(5) # Pause 5 second after each request   
        
    return information_list_al

# %%
information_list_al = extract_laptop_urls_al(page_urls_al) # To create the list with information per laptop
information_list_al
# Out:
# [{'title': 'Lenovo ThinkBook 15 G2 - 20VE0049MH',
#   'url': 'https://www.coolblue.nl/en/product/872868/lenovo-thinkbook-15-g2-20ve0049mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.059,-</strong>},
#  {'title': 'HP 15s-fq2960nd',
#   'url': 'https://www.coolblue.nl/en/product/873236/hp-15s-fq2960nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">499,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Apple MacBook Air (2020) 16GB/256GB Apple M1 with 7-core GPU Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/874171/apple-macbook-air-2020-16gb-256gb-apple-m1-with-7-core-gpu-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.359,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 14ARE05 81YM00F7MH',
#   'url': 'https://www.coolblue.nl/en/product/900571/lenovo-ideapad-5-14are05-81ym00f7mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">749,-</strong>},
#  {'title': 'Apple MacBook Pro 13 inches (2020) 16GB/256GB Apple M1 Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/874177/apple-macbook-pro-13-inches-2020-16gb-256gb-apple-m1-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.609,-</strong>},
#  {'title': 'HP Pavilion 15-eh1907nd',
#   'url': 'https://www.coolblue.nl/en/product/889428/hp-pavilion-15-eh1907nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">599,-</strong>},
#  {'title': 'Lenovo ThinkBook 15 G2 - 20VE0046MH',
#   'url': 'https://www.coolblue.nl/en/product/872864/lenovo-thinkbook-15-g2-20ve0046mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">799,-</strong>},
#  {'title': 'HP Pavilion 15-eh1908nd',
#   'url': 'https://www.coolblue.nl/en/product/889429/hp-pavilion-15-eh1908nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">679,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 Pro 14ACN6 82L7006VMH',
#   'url': 'https://www.coolblue.nl/en/product/878296/lenovo-ideapad-5-pro-14acn6-82l7006vmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">999,-</strong>},
#  {'title': 'Apple MacBook Pro 13 inches (2020) 16GB/512GB Apple M1 Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/874178/apple-macbook-pro-13-inches-2020-16gb-512gb-apple-m1-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.769,-</strong>},
#  {'title': 'HP ProBook 450 G8 - 203F7EA',
#   'url': 'https://www.coolblue.nl/en/product/872309/hp-probook-450-g8-203f7ea.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.149,-</strong>},
#  {'title': 'Apple MacBook Pro 14 inches (2021) M1 Pro (8-core CPU/14-core GPU) 16GB/1TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894397/apple-macbook-pro-14-inches-2021-m1-pro-8-core-cpu-14-core-gpu-16gb-1tb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.329,-</strong>},
#  {'title': 'Acer Swift 3 SF316-51-51BS',
#   'url': 'https://www.coolblue.nl/en/product/879388/acer-swift-3-sf316-51-51bs.html',
#   'price': <strong class="sales-price__current js-sales-price-current">769,-</strong>},
#  {'title': 'Apple MacBook Pro 14 inches (2021) M1 Pro (8-core CPU/14-core GPU) 32GB/1TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894399/apple-macbook-pro-14-inches-2021-m1-pro-8-core-cpu-14-core-gpu-32gb-1tb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.879,-</strong>},
#  {'title': 'Apple MacBook Pro 14 inches (2021) M1 Pro (8-core CPU/14-core GPU) 16GB/512GB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894361/apple-macbook-pro-14-inches-2021-m1-pro-8-core-cpu-14-core-gpu-16gb-512gb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.099,-</strong>},
#  {'title': 'Lenovo Legion 5 17ITH6H 82JM001EMH',
#   'url': 'https://www.coolblue.nl/en/product/882868/lenovo-legion-5-17ith6h-82jm001emh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.499,-</strong>},
#  {'title': 'Apple MacBook Air (2020) 16GB/512GB Apple M1 with 8-core GPU Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/874175/apple-macbook-air-2020-16gb-512gb-apple-m1-with-8-core-gpu-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.509,-</strong>},
#  {'title': 'Lenovo Legion 5 17IMH05 82B300CBMH',
#   'url': 'https://www.coolblue.nl/en/product/882865/lenovo-legion-5-17imh05-82b300cbmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.199,-</strong>},
#  {'title': 'HP 470 G8 i7-16gb-512GB',
#   'url': 'https://www.coolblue.nl/en/product/889652/hp-470-g8-i7-16gb-512gb.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.349,-</strong>},
#  {'title': 'Apple MacBook Pro 14 inches (2021) M1 Pro (10-core CPU/16-core GPU) 32GB/1TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894403/apple-macbook-pro-14-inches-2021-m1-pro-10-core-cpu-16-core-gpu-32gb-1tb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">3.139,-</strong>},
#  {'title': 'MSI GL66 Pulse 11UEK-036NL',
#   'url': 'https://www.coolblue.nl/en/product/880208/msi-gl66-pulse-11uek-036nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.399,-</strong>},
#  {'title': 'Apple MacBook Pro 14 inches (2021) M1 Pro (10-core CPU/16-core GPU) 32GB/512GB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894402/apple-macbook-pro-14-inches-2021-m1-pro-10-core-cpu-16-core-gpu-32gb-512gb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.919,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Apple MacBook Pro 14 inches (2021) M1 Pro (10-core CPU/16-core GPU) 32GB/512GB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894402/apple-macbook-pro-14-inches-2021-m1-pro-10-core-cpu-16-core-gpu-32gb-512gb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.919,-</strong>},
#  {'title': 'HP 17-cn0976nd',
#   'url': 'https://www.coolblue.nl/en/product/891408/hp-17-cn0976nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.049,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'HP Chromebook 14a-na0170nd',
#   'url': 'https://www.coolblue.nl/en/product/868651/hp-chromebook-14a-na0170nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">249,-</strong>},
#  {'title': 'HP ProBook 440 G8 - 203F0EA',
#   'url': 'https://www.coolblue.nl/en/product/872297/hp-probook-440-g8-203f0ea.html',
#   'price': <strong class="sales-price__current js-sales-price-current">999,-</strong>},
#  {'title': 'MSI GF63 Thin 10SC-683NL',
#   'url': 'https://www.coolblue.nl/en/product/891437/msi-gf63-thin-10sc-683nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">799,-</strong>},
#  {'title': 'Microsoft Surface Pro 8 - i5/16/256 (Graphite)',
#   'url': 'https://www.coolblue.nl/en/product/897655/microsoft-surface-pro-8-i5-16-256-graphite.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.249,-</strong>},
#  {'title': 'MSI Modern 15 A11M-814NL',
#   'url': 'https://www.coolblue.nl/en/product/892840/msi-modern-15-a11m-814nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">799,-</strong>},
#  {'title': 'Apple MacBook Pro 16 inches (2021) M1 Pro (10-core CPU/16-core GPU) 16GB/1TB Silver',
#   'url': 'https://www.coolblue.nl/en/product/894372/apple-macbook-pro-16-inches-2021-m1-pro-10-core-cpu-16-core-gpu-16gb-1tb-silver.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.979,-</strong>},
#  {'title': 'Apple MacBook Pro 14 inches (2021) M1 Pro (8-core CPU/14-core GPU) 32GB/512GB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894398/apple-macbook-pro-14-inches-2021-m1-pro-8-core-cpu-14-core-gpu-32gb-512gb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.609,-</strong>},
#  {'title': 'Apple MacBook Air (2020) 16GB/1TB Apple M1 with 8-core GPU Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/874176/apple-macbook-air-2020-16gb-1tb-apple-m1-with-8-core-gpu-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.839,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 14ITL05 82FE00PWMH',
#   'url': 'https://www.coolblue.nl/en/product/878306/lenovo-ideapad-5-14itl05-82fe00pwmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">749,-</strong>},
#  {'title': 'Acer Swift 3 SF314-43-R13Q',
#   'url': 'https://www.coolblue.nl/en/product/882455/acer-swift-3-sf314-43-r13q.html',
#   'price': <strong class="sales-price__current js-sales-price-current">579,-</strong>},
#  {'title': 'HP 17-cn1959nd',
#   'url': 'https://www.coolblue.nl/en/product/899604/hp-17-cn1959nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">849,-</strong>},
#  {'title': 'Acer Chromebook Spin 514 CP514-1HH-R7PK',
#   'url': 'https://www.coolblue.nl/en/product/876297/acer-chromebook-spin-514-cp514-1hh-r7pk.html',
#   'price': <strong class="sales-price__current js-sales-price-current">649,-</strong>},
#  {'title': 'MSI Creator 17 B11UH-404NL',
#   'url': 'https://www.coolblue.nl/en/product/889901/msi-creator-17-b11uh-404nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.499,-</strong>},
#  {'title': 'Lenovo IdeaPad Gaming 3 15ACH6 82K200ANMH',
#   'url': 'https://www.coolblue.nl/en/product/879991/lenovo-ideapad-gaming-3-15ach6-82k200anmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">799,-</strong>},
#  {'title': 'Lenovo V17 G2 - 82NX00EAMH',
#   'url': 'https://www.coolblue.nl/en/product/888358/lenovo-v17-g2-82nx00eamh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.199,-</strong>},
#  {'title': 'MSI Creator 17 B11UE-408NL',
#   'url': 'https://www.coolblue.nl/en/product/889899/msi-creator-17-b11ue-408nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.699,-</strong>},
#  {'title': 'HP Pavilion 15-eh1977nd',
#   'url': 'https://www.coolblue.nl/en/product/889431/hp-pavilion-15-eh1977nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">949,-</strong>},
#  {'title': 'Asus Chromebook C523NA-EJ0446',
#   'url': 'https://www.coolblue.nl/en/product/886177/asus-chromebook-c523na-ej0446.html',
#   'price': <strong class="sales-price__current js-sales-price-current">299,-</strong>},
#  {'title': 'MSI Summit E16 Flip Evo A11MT-037NL',
#   'url': 'https://www.coolblue.nl/en/product/886479/msi-summit-e16-flip-evo-a11mt-037nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.349,-</strong>},
#  {'title': 'HP 15s-fq4965nd',
#   'url': 'https://www.coolblue.nl/en/product/891962/hp-15s-fq4965nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">639,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Apple MacBook Pro 16 inches (2021) M1 Pro (10-core CPU/16-core GPU) 16GB/1TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894371/apple-macbook-pro-16-inches-2021-m1-pro-10-core-cpu-16-core-gpu-16gb-1tb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.799,-</strong>},
#  {'title': 'HP Pavilion x360 14-dy0902nd',
#   'url': 'https://www.coolblue.nl/en/product/877670/hp-pavilion-x360-14-dy0902nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">719,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Lenovo Legion 5 15IMH05H 81Y60090MH',
#   'url': 'https://www.coolblue.nl/en/product/873077/lenovo-legion-5-15imh05h-81y60090mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.199,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 14ITL05 82FE00PSMH',
#   'url': 'https://www.coolblue.nl/en/product/878381/lenovo-ideapad-5-14itl05-82fe00psmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">529,-</strong>},
#  {'title': 'Acer Aspire Vero AV15-51-574G',
#   'url': 'https://www.coolblue.nl/en/product/892461/acer-aspire-vero-av15-51-574g.html',
#   'price': <strong class="sales-price__current js-sales-price-current">799,-</strong>},
#  {'title': 'Apple MacBook Pro 16 inches (2021) M1 Max (10-core CPU/24-core GPU) 64GB/1TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894448/apple-macbook-pro-16-inches-2021-m1-max-10-core-cpu-24-core-gpu-64gb-1tb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">4.129,-</strong>},
#  {'title': 'Apple MacBook Pro 16 inches (2021) M1 Max (10-core CPU/32-core GPU) 32GB/512GB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894450/apple-macbook-pro-16-inches-2021-m1-max-10-core-cpu-32-core-gpu-32gb-512gb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">3.619,-</strong>},
#  {'title': 'Microsoft Surface Laptop Go - i5 - 8GB - 128GB Platinum',
#   'url': 'https://www.coolblue.nl/en/product/869660/microsoft-surface-laptop-go-i5-8gb-128gb-platinum.html',
#   'price': <strong class="sales-price__current js-sales-price-current">599,-</strong>},
#  {'title': 'Acer Aspire 5 A514-54-59FF',
#   'url': 'https://www.coolblue.nl/en/product/867584/acer-aspire-5-a514-54-59ff.html',
#   'price': <strong class="sales-price__current js-sales-price-current">549,-</strong>},
#  {'title': 'Apple MacBook Pro 16 inches (2021) M1 Pro (10-core CPU/16-core GPU) 16GB/2TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894442/apple-macbook-pro-16-inches-2021-m1-pro-10-core-cpu-16-core-gpu-16gb-2tb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">3.119,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 15ITL05 82FG00YRMH',
#   'url': 'https://www.coolblue.nl/en/product/878377/lenovo-ideapad-5-15itl05-82fg00yrmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">629,-</strong>},
#  {'title': 'Apple MacBook Pro 16 inches (2021) M1 Max (10-core CPU/32-core GPU) 32GB/2TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894451/apple-macbook-pro-16-inches-2021-m1-max-10-core-cpu-32-core-gpu-32gb-2tb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">4.309,-</strong>},
#  {'title': 'Asus Zenbook Flip 15 UM562IA-EZ012T',
#   'url': 'https://www.coolblue.nl/en/product/886718/asus-zenbook-flip-15-um562ia-ez012t.html',
#   'price': <strong class="sales-price__current js-sales-price-current">899,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 15ITL05 82FG01FEMH',
#   'url': 'https://www.coolblue.nl/en/product/891620/lenovo-ideapad-5-15itl05-82fg01femh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">779,-</strong>},
#  {'title': 'MSI Katana GF76 11SC-470NL',
#   'url': 'https://www.coolblue.nl/en/product/891494/msi-katana-gf76-11sc-470nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.099,-</strong>},
#  {'title': 'HP 17-cn1915nd',
#   'url': 'https://www.coolblue.nl/en/product/890652/hp-17-cn1915nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">739,-</strong>},
#  {'title': 'Apple MacBook Pro 16 inches (2021) M1 Pro (10-core CPU/16-core GPU) 32GB/2TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894445/apple-macbook-pro-16-inches-2021-m1-pro-10-core-cpu-16-core-gpu-32gb-2tb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">3.839,-</strong>},
#  {'title': 'Microsoft Surface Pro 8 - i7/16/512 (Platinum)',
#   'url': 'https://www.coolblue.nl/en/product/897658/microsoft-surface-pro-8-i7-16-512-platinum.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.699,-</strong>},
#  {'title': 'Acer Aspire 3 A315-56-59Y1',
#   'url': 'https://www.coolblue.nl/en/product/841240/acer-aspire-3-a315-56-59y1.html',
#   'price': <strong class="sales-price__current js-sales-price-current">549,-</strong>},
#  {'title': 'Apple MacBook Pro 16 inches (2021) M1 Max (10-core CPU/32-core GPU) 64GB/4TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894455/apple-macbook-pro-16-inches-2021-m1-max-10-core-cpu-32-core-gpu-64gb-4tb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">5.459,-</strong>},
#  {'title': 'HP Pavilion x360 14-dy0900nd',
#   'url': 'https://www.coolblue.nl/en/product/877668/hp-pavilion-x360-14-dy0900nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">549,-</strong>},
#  {'title': 'Lenovo Legion 5 Pro 16ITH6H 82JD00ASMH',
#   'url': 'https://www.coolblue.nl/en/product/898360/lenovo-legion-5-pro-16ith6h-82jd00asmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.369,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'HP EliteBook 850 G8 - 2Y2S4EA',
#   'url': 'https://www.coolblue.nl/en/product/889655/hp-elitebook-850-g8-2y2s4ea.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.699,-</strong>},
#  {'title': 'Apple MacBook Air (2020) 16GB/512GB Apple M1 with 8-core GPU Gold',
#   'url': 'https://www.coolblue.nl/en/product/878573/apple-macbook-air-2020-16gb-512gb-apple-m1-with-8-core-gpu-gold.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.579,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Asus Zenbook 14 UX425JA-HM025T',
#   'url': 'https://www.coolblue.nl/en/product/892619/asus-zenbook-14-ux425ja-hm025t.html',
#   'price': <strong class="sales-price__current js-sales-price-current">879,-</strong>},
#  {'title': 'Asus ExpertBook B1500CEAE-BQ2008R',
#   'url': 'https://www.coolblue.nl/en/product/890744/asus-expertbook-b1500ceae-bq2008r.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.099,-</strong>},
#  {'title': 'HP Pavilion G 15-dk2980nd',
#   'url': 'https://www.coolblue.nl/en/product/879741/hp-pavilion-g-15-dk2980nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">949,-</strong>},
#  {'title': 'Lenovo Legion 5 15ITH6H 82JH005NMH',
#   'url': 'https://www.coolblue.nl/en/product/882857/lenovo-legion-5-15ith6h-82jh005nmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.549,-</strong>},
#  {'title': 'Apple MacBook Pro 13 inches (2020) 16GB/1TB Apple M1 Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/874179/apple-macbook-pro-13-inches-2020-16gb-1tb-apple-m1-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.049,-</strong>},
#  {'title': 'MSI GF66 Katana 11UG-261NL',
#   'url': 'https://www.coolblue.nl/en/product/884356/msi-gf66-katana-11ug-261nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.499,-</strong>},
#  {'title': 'MSI GL66 Pulse 11UDK-025NL',
#   'url': 'https://www.coolblue.nl/en/product/880137/msi-gl66-pulse-11udk-025nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.199,-</strong>},
#  {'title': 'Asus Chromebook C434TA-AI0485',
#   'url': 'https://www.coolblue.nl/en/product/886176/asus-chromebook-c434ta-ai0485.html',
#   'price': <strong class="sales-price__current js-sales-price-current">619,-</strong>},
#  {'title': 'Apple MacBook Pro 14 inches (2021) M1 Pro (8-core CPU/14-core GPU) 16GB/512GB Silver',
#   'url': 'https://www.coolblue.nl/en/product/894362/apple-macbook-pro-14-inches-2021-m1-pro-8-core-cpu-14-core-gpu-16gb-512gb-silver.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.019,-</strong>},
#  {'title': 'Lenovo IdeaPad Flex 5 15ITL05 82HT0057MH',
#   'url': 'https://www.coolblue.nl/en/product/878333/lenovo-ideapad-flex-5-15itl05-82ht0057mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">799,-</strong>},
#  {'title': 'Apple MacBook Pro 16 inches (2021) M1 Pro (10-core CPU/16-core GPU) 16GB/512GB Silver',
#   'url': 'https://www.coolblue.nl/en/product/894370/apple-macbook-pro-16-inches-2021-m1-pro-10-core-cpu-16-core-gpu-16gb-512gb-silver.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.499,-</strong>},
#  {'title': 'Apple MacBook Pro 14 inches (2021) M1 Pro (10-core CPU/16-core GPU) 16GB/1TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894363/apple-macbook-pro-14-inches-2021-m1-pro-10-core-cpu-16-core-gpu-16gb-1tb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.469,-</strong>},
#  {'title': 'Acer Aspire 5 A517-52-52U6',
#   'url': 'https://www.coolblue.nl/en/product/872282/acer-aspire-5-a517-52-52u6.html',
#   'price': <strong class="sales-price__current js-sales-price-current">699,-</strong>},
#  {'title': 'HP Pavilion x360 14-dy0905nd',
#   'url': 'https://www.coolblue.nl/en/product/877673/hp-pavilion-x360-14-dy0905nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">679,-</strong>},
#  {'title': 'HP Pavilion 15-eg1900nd',
#   'url': 'https://www.coolblue.nl/en/product/897883/hp-pavilion-15-eg1900nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.129,-</strong>},
#  {'title': 'HP 17-cp0936nd',
#   'url': 'https://www.coolblue.nl/en/product/890656/hp-17-cp0936nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">549,-</strong>},
#  {'title': 'HP VICTUS 16-e0306nd',
#   'url': 'https://www.coolblue.nl/en/product/897735/hp-victus-16-e0306nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">999,-</strong>},
#  {'title': 'Apple MacBook Air (2020) 16GB/256GB Apple M1 with 7-core GPU Gold',
#   'url': 'https://www.coolblue.nl/en/product/874173/apple-macbook-air-2020-16gb-256gb-apple-m1-with-7-core-gpu-gold.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.339,-</strong>},
#  {'title': 'HP 17-cn0970nd',
#   'url': 'https://www.coolblue.nl/en/product/878104/hp-17-cn0970nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">899,-</strong>},
#  {'title': 'Lenovo Legion 5 17IMH05H 81Y800A8MH',
#   'url': 'https://www.coolblue.nl/en/product/882866/lenovo-legion-5-17imh05h-81y800a8mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.369,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Acer Chromebook Spin 311 CP311-2H-C3DE',
#   'url': 'https://www.coolblue.nl/en/product/853049/acer-chromebook-spin-311-cp311-2h-c3de.html',
#   'price': <strong class="sales-price__current js-sales-price-current">249,-</strong>},
#  {'title': 'Samsung Galaxy Book2 Pro 360 15 NP950QED-KA1NL',
#   'url': 'https://www.coolblue.nl/en/product/901777/samsung-galaxy-book2-pro-360-15-np950qed-ka1nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.599,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Apple MacBook Pro 14 inches (2021) M1 Max (10-core CPU/32-core GPU) 64GB/2TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894417/apple-macbook-pro-14-inches-2021-m1-max-10-core-cpu-32-core-gpu-64gb-2tb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">4.499,-</strong>},
#  {'title': 'Microsoft Surface Pro 8 - i7/16/512 (Graphite)',
#   'url': 'https://www.coolblue.nl/en/product/897659/microsoft-surface-pro-8-i7-16-512-graphite.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.699,-</strong>},
#  {'title': 'Apple MacBook Pro 14 inches (2021) M1 Pro (10-core CPU/16-core GPU) 32GB/2TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894404/apple-macbook-pro-14-inches-2021-m1-pro-10-core-cpu-16-core-gpu-32gb-2tb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">3.399,-</strong>},
#  {'title': 'Apple MacBook Air (2020) 16GB/512GB Apple M1 with 8-core GPU Silver',
#   'url': 'https://www.coolblue.nl/en/product/878572/apple-macbook-air-2020-16gb-512gb-apple-m1-with-8-core-gpu-silver.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.569,-</strong>},
#  {'title': 'Lenovo IdeaPad Flex 5 14ITL05 82HS00K5MH',
#   'url': 'https://www.coolblue.nl/en/product/878316/lenovo-ideapad-flex-5-14itl05-82hs00k5mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.049,-</strong>},
#  {'title': 'Lenovo Legion 5 Pro 16ITH6H 82JD00AQMH',
#   'url': 'https://www.coolblue.nl/en/product/900578/lenovo-legion-5-pro-16ith6h-82jd00aqmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.099,-</strong>},
#  {'title': 'HP EliteBook 840 G8 - 35T73EA',
#   'url': 'https://www.coolblue.nl/en/product/889659/hp-elitebook-840-g8-35t73ea.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.769,-</strong>},
#  {'title': 'HP Pavilion G 15-dk2990nd',
#   'url': 'https://www.coolblue.nl/en/product/879742/hp-pavilion-g-15-dk2990nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.099,-</strong>},
#  {'title': 'Lenovo Legion 5 Pro 16ACH6H 82JQ00QPMH',
#   'url': 'https://www.coolblue.nl/en/product/898108/lenovo-legion-5-pro-16ach6h-82jq00qpmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.949,-</strong>},
#  {'title': 'Apple MacBook Air (2020) MGN63N/A Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/873113/apple-macbook-air-2020-mgn63n-a-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">999,-</strong>},
#  {'title': 'HP Pavilion G 15-ec2905nd',
#   'url': 'https://www.coolblue.nl/en/product/879737/hp-pavilion-g-15-ec2905nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">849,-</strong>},
#  {'title': 'HP EliteBook 850 G8 - 2Y2S3EA',
#   'url': 'https://www.coolblue.nl/en/product/889654/hp-elitebook-850-g8-2y2s3ea.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.849,-</strong>},
#  {'title': 'Apple MacBook Pro 16 inches (2021) M1 Max (10-core CPU/24-core GPU) 64GB/2TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894449/apple-macbook-pro-16-inches-2021-m1-max-10-core-cpu-24-core-gpu-64gb-2tb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">4.499,-</strong>},
#  {'title': 'Asus Vivobook 15 OLED K513EA-L11387W',
#   'url': 'https://www.coolblue.nl/en/product/898538/asus-vivobook-15-oled-k513ea-l11387w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.099,-</strong>},
#  {'title': 'HP 17-cn1951nd',
#   'url': 'https://www.coolblue.nl/en/product/890653/hp-17-cn1951nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">799,-</strong>},
#  {'title': 'Asus Vivobook 17 X712EA-AU602W',
#   'url': 'https://www.coolblue.nl/en/product/898537/asus-vivobook-17-x712ea-au602w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">999,-</strong>},
#  {'title': 'Lenovo ThinkPad E15 G2 - 20TD0028MH',
#   'url': 'https://www.coolblue.nl/en/product/872898/lenovo-thinkpad-e15-g2-20td0028mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">999,-</strong>},
#  {'title': 'Lenovo ThinkBook 15 G3 - 21A4002DMH',
#   'url': 'https://www.coolblue.nl/en/product/888360/lenovo-thinkbook-15-g3-21a4002dmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">849,-</strong>},
#  {'title': 'Asus Zenbook 14 UM425UAZ-KI023W',
#   'url': 'https://www.coolblue.nl/en/product/893967/asus-zenbook-14-um425uaz-ki023w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.049,-</strong>},
#  {'title': 'Lenovo IdeaPad Gaming 3 15IMH05 81Y40197MH',
#   'url': 'https://www.coolblue.nl/en/product/880001/lenovo-ideapad-gaming-3-15imh05-81y40197mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">899,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Acer Nitro 5 AN517-52-757K',
#   'url': 'https://www.coolblue.nl/en/product/867668/acer-nitro-5-an517-52-757k.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.099,-</strong>},
#  {'title': 'Acer Chromebook Spin 513 CP513-1H-S2LW',
#   'url': 'https://www.coolblue.nl/en/product/872378/acer-chromebook-spin-513-cp513-1h-s2lw.html',
#   'price': <strong class="sales-price__current js-sales-price-current">299,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Microsoft Surface Pro 8 - i5/8/256 (Graphite)',
#   'url': 'https://www.coolblue.nl/en/product/897653/microsoft-surface-pro-8-i5-8-256-graphite.html',
#   'price': <strong class="sales-price__current js-sales-price-current">999,-</strong>},
#  {'title': 'Acer Chromebook 314 CB314-1HT-C6XM',
#   'url': 'https://www.coolblue.nl/en/product/839397/acer-chromebook-314-cb314-1ht-c6xm.html',
#   'price': <strong class="sales-price__current js-sales-price-current">349,-</strong>},
#  {'title': 'Microsoft Surface Pro 8 - i5/8GB/128GB (Platinum)',
#   'url': 'https://www.coolblue.nl/en/product/897650/microsoft-surface-pro-8-i5-8gb-128gb-platinum.html',
#   'price': <strong class="sales-price__current js-sales-price-current">949,-</strong>},
#  {'title': 'HP ENVY x360 15-ed1900nd',
#   'url': 'https://www.coolblue.nl/en/product/871004/hp-envy-x360-15-ed1900nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.199,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 15ITL05 82FG00YQMH',
#   'url': 'https://www.coolblue.nl/en/product/878365/lenovo-ideapad-5-15itl05-82fg00yqmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">699,-</strong>},
#  {'title': 'HP Pavilion x360 14-dy0901nd',
#   'url': 'https://www.coolblue.nl/en/product/877669/hp-pavilion-x360-14-dy0901nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">819,-</strong>},
#  {'title': 'Acer Nitro 5 AN515-57-77K2',
#   'url': 'https://www.coolblue.nl/en/product/892321/acer-nitro-5-an515-57-77k2.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.499,-</strong>},
#  {'title': 'Lenovo Legion 7 16ACHg8 82N600MTMH',
#   'url': 'https://www.coolblue.nl/en/product/898112/lenovo-legion-7-16achg8-82n600mtmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">3.099,-</strong>},
#  {'title': 'MSI GE66 11UH-203NL',
#   'url': 'https://www.coolblue.nl/en/product/883217/msi-ge66-11uh-203nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.549,-</strong>},
#  {'title': 'Acer Aspire 3 A315-56-577F',
#   'url': 'https://www.coolblue.nl/en/product/841243/acer-aspire-3-a315-56-577f.html',
#   'price': <strong class="sales-price__current js-sales-price-current">549,-</strong>},
#  {'title': 'MSI Creator 17 B11UG-406NL',
#   'url': 'https://www.coolblue.nl/en/product/889900/msi-creator-17-b11ug-406nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.899,-</strong>},
#  {'title': 'HP 15s-eq2920nd',
#   'url': 'https://www.coolblue.nl/en/product/876357/hp-15s-eq2920nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">569,-</strong>},
#  {'title': 'Acer Swift 3 SF314-511-577W',
#   'url': 'https://www.coolblue.nl/en/product/882458/acer-swift-3-sf314-511-577w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">799,-</strong>},
#  {'title': 'Acer TravelMate P2 TMP215-53-7159',
#   'url': 'https://www.coolblue.nl/en/product/871419/acer-travelmate-p2-tmp215-53-7159.html',
#   'price': <strong class="sales-price__current js-sales-price-current">999,-</strong>},
#  {'title': 'Lenovo IdeaPad Flex 5 14ITL05 82HS00K4MH',
#   'url': 'https://www.coolblue.nl/en/product/878313/lenovo-ideapad-flex-5-14itl05-82hs00k4mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">629,-</strong>},
#  {'title': 'HP Chromebook x360 14b-ca0360nd',
#   'url': 'https://www.coolblue.nl/en/product/868653/hp-chromebook-x360-14b-ca0360nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">349,-</strong>},
#  {'title': 'HP Pavilion x360 14-dy1904nd',
#   'url': 'https://www.coolblue.nl/en/product/890670/hp-pavilion-x360-14-dy1904nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.099,-</strong>},
#  {'title': 'Lenovo Thinkpad P14s G2 - 20VX005LMH',
#   'url': 'https://www.coolblue.nl/en/product/886850/lenovo-thinkpad-p14s-g2-20vx005lmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.999,-</strong>},
#  {'title': 'MSI GF65 10UE-087NL',
#   'url': 'https://www.coolblue.nl/en/product/875603/msi-gf65-10ue-087nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.399,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 14ALC05 82LM008BMH',
#   'url': 'https://www.coolblue.nl/en/product/898568/lenovo-ideapad-5-14alc05-82lm008bmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">629,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Lenovo IdeaPad 3 17ADA6 82KS001CMH',
#   'url': 'https://www.coolblue.nl/en/product/890752/lenovo-ideapad-3-17ada6-82ks001cmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">629,-</strong>},
#  {'title': 'ASUS TUF Dash F15FX517ZM-HN073W',
#   'url': 'https://www.coolblue.nl/en/product/898544/asus-tuf-dash-f15fx517zm-hn073w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.679,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'MSI Raider GE76 Deluxe Edition 12UGS-684NL',
#   'url': 'https://www.coolblue.nl/en/product/899579/msi-raider-ge76-deluxe-edition-12ugs-684nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">3.199,-</strong>},
#  {'title': 'Acer Aspire 3 A315-58-39YC',
#   'url': 'https://www.coolblue.nl/en/product/882445/acer-aspire-3-a315-58-39yc.html',
#   'price': <strong class="sales-price__current js-sales-price-current">479,-</strong>},
#  {'title': 'Asus X515EA-EJ1474W',
#   'url': 'https://www.coolblue.nl/en/product/893939/asus-x515ea-ej1474w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">749,-</strong>},
#  {'title': 'HP ENVY x360 15-eu0991nd',
#   'url': 'https://www.coolblue.nl/en/product/890665/hp-envy-x360-15-eu0991nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.199,-</strong>},
#  {'title': 'Acer Aspire 3 A315-23-R1K8',
#   'url': 'https://www.coolblue.nl/en/product/861465/acer-aspire-3-a315-23-r1k8.html',
#   'price': <strong class="sales-price__current js-sales-price-current">499,-</strong>},
#  {'title': 'HP Pavilion x360 15-er0951nd',
#   'url': 'https://www.coolblue.nl/en/product/890672/hp-pavilion-x360-15-er0951nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">789,-</strong>},
#  {'title': 'HP Pavilion x360 14-dy1903nd',
#   'url': 'https://www.coolblue.nl/en/product/890669/hp-pavilion-x360-14-dy1903nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.179,-</strong>},
#  {'title': 'Asus Vivobook Pro 15 K3500PH-L1113W',
#   'url': 'https://www.coolblue.nl/en/product/893958/asus-vivobook-pro-15-k3500ph-l1113w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.299,-</strong>},
#  {'title': 'Lenovo V17 G2 - 82NX00E9MH',
#   'url': 'https://www.coolblue.nl/en/product/888357/lenovo-v17-g2-82nx00e9mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">849,-</strong>},
#  {'title': 'Apple MacBook Pro 14 inches (2021) M1 Max (10-core CPU/24-core GPU) 32GB/2TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894407/apple-macbook-pro-14-inches-2021-m1-max-10-core-cpu-24-core-gpu-32gb-2tb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">3.899,-</strong>},
#  {'title': 'Asus Vivobook Go 14 E410MA-BV1312WS',
#   'url': 'https://www.coolblue.nl/en/product/898504/asus-vivobook-go-14-e410ma-bv1312ws.html',
#   'price': <strong class="sales-price__current js-sales-price-current">289,-</strong>},
#  {'title': 'Lenovo IdeaPad Flex 5 15ITL05 82HT0056MH',
#   'url': 'https://www.coolblue.nl/en/product/878332/lenovo-ideapad-flex-5-15itl05-82ht0056mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">699,-</strong>},
#  {'title': 'MSI GF63 Thin 10UC-685NL',
#   'url': 'https://www.coolblue.nl/en/product/891438/msi-gf63-thin-10uc-685nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.049,-</strong>},
#  {'title': 'Apple MacBook Air (2020) 16GB/256GB Apple M1 with 7-core GPU Silver',
#   'url': 'https://www.coolblue.nl/en/product/874172/apple-macbook-air-2020-16gb-256gb-apple-m1-with-7-core-gpu-silver.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.339,-</strong>},
#  {'title': 'HP Pavilion 15-eg0900nd',
#   'url': 'https://www.coolblue.nl/en/product/869785/hp-pavilion-15-eg0900nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">979,-</strong>},
#  {'title': 'MSI GF66 Katana 11UC-811NL',
#   'url': 'https://www.coolblue.nl/en/product/889892/msi-gf66-katana-11uc-811nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.049,-</strong>},
#  {'title': 'MSI Stealth GS66 12UGS-259NL',
#   'url': 'https://www.coolblue.nl/en/product/899582/msi-stealth-gs66-12ugs-259nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">3.149,-</strong>},
#  {'title': 'HP 14s-fq1971nd',
#   'url': 'https://www.coolblue.nl/en/product/891955/hp-14s-fq1971nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">699,-</strong>},
#  {'title': 'Apple MacBook Pro 14 inches (2021) M1 Pro (10-core CPU/16-core GPU) 16GB/512GB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894401/apple-macbook-pro-14-inches-2021-m1-pro-10-core-cpu-16-core-gpu-16gb-512gb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.289,-</strong>},
#  {'title': 'HP Pavilion G 15-dk2970nd',
#   'url': 'https://www.coolblue.nl/en/product/879740/hp-pavilion-g-15-dk2970nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">899,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Lenovo IdeaPad 5 Pro 16ACH6 82L500KNMH',
#   'url': 'https://www.coolblue.nl/en/product/891629/lenovo-ideapad-5-pro-16ach6-82l500knmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">949,-</strong>},
#  {'title': 'Lenovo IdeaPad 3 14ITL6 82H700JWMH',
#   'url': 'https://www.coolblue.nl/en/product/878357/lenovo-ideapad-3-14itl6-82h700jwmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">479,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Lenovo IdeaPad 3 15ITL6 82H800SAMH',
#   'url': 'https://www.coolblue.nl/en/product/878363/lenovo-ideapad-3-15itl6-82h800samh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">449,-</strong>},
#  {'title': 'Lenovo IdeaPad 3 15ITL05 81X800HTMH',
#   'url': 'https://www.coolblue.nl/en/product/891609/lenovo-ideapad-3-15itl05-81x800htmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">549,-</strong>},
#  {'title': 'Asus Zenbook 13 UM325UA-KG127W',
#   'url': 'https://www.coolblue.nl/en/product/893965/asus-zenbook-13-um325ua-kg127w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">949,-</strong>},
#  {'title': 'Lenovo IdeaPad Gaming 3 15IMH05 81Y400GGMH',
#   'url': 'https://www.coolblue.nl/en/product/860847/lenovo-ideapad-gaming-3-15imh05-81y400ggmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">749,-</strong>},
#  {'title': 'Lenovo Chromebook IdeaPad Flex 5 13IML05 82B8000SMH',
#   'url': 'https://www.coolblue.nl/en/product/860582/lenovo-chromebook-ideapad-flex-5-13iml05-82b8000smh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">479,-</strong>},
#  {'title': 'Asus Vivobook Pro 15 OLED M3500QC-L1079W',
#   'url': 'https://www.coolblue.nl/en/product/898539/asus-vivobook-pro-15-oled-m3500qc-l1079w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.149,-</strong>},
#  {'title': 'HP 17-cn1956nd',
#   'url': 'https://www.coolblue.nl/en/product/890654/hp-17-cn1956nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">999,-</strong>},
#  {'title': 'Acer Chromebook Spin 513 CP513-1H-S4MH',
#   'url': 'https://www.coolblue.nl/en/product/872005/acer-chromebook-spin-513-cp513-1h-s4mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">499,-</strong>},
#  {'title': 'Asus Zenbook Flip 15 UX564PH-EZ012W',
#   'url': 'https://www.coolblue.nl/en/product/893974/asus-zenbook-flip-15-ux564ph-ez012w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.499,-</strong>},
#  {'title': 'HP Zbook Firefly 15 G8 - 2C9S5EA',
#   'url': 'https://www.coolblue.nl/en/product/879313/hp-zbook-firefly-15-g8-2c9s5ea.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.069,-</strong>},
#  {'title': 'Samsung Galaxy Book2 Pro 15 NP950XED-KF2NL',
#   'url': 'https://www.coolblue.nl/en/product/901779/samsung-galaxy-book2-pro-15-np950xed-kf2nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.499,-</strong>},
#  {'title': 'Lenovo ThinkPad X1 Carbon G9 - 20XW0029MH',
#   'url': 'https://www.coolblue.nl/en/product/884784/lenovo-thinkpad-x1-carbon-g9-20xw0029mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.899,-</strong>},
#  {'title': 'MSI Creator M16 A11UD-853NL',
#   'url': 'https://www.coolblue.nl/en/product/889898/msi-creator-m16-a11ud-853nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.349,-</strong>},
#  {'title': 'Asus Vivobook 14 X415EA-EB851W',
#   'url': 'https://www.coolblue.nl/en/product/898530/asus-vivobook-14-x415ea-eb851w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">629,-</strong>},
#  {'title': 'Asus Vivobook Pro 16X N7600PC-KV077W',
#   'url': 'https://www.coolblue.nl/en/product/893963/asus-vivobook-pro-16x-n7600pc-kv077w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.449,-</strong>},
#  {'title': 'Lenovo ThinkBook 15p - 20V30038MH',
#   'url': 'https://www.coolblue.nl/en/product/877932/lenovo-thinkbook-15p-20v30038mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">999,-</strong>},
#  {'title': 'Asus TUF Dash\xa0F15 FX516PC-HN082T',
#   'url': 'https://www.coolblue.nl/en/product/888552/asus-tuf-dash-f15-fx516pc-hn082t.html',
#   'price': <strong class="sales-price__current js-sales-price-current">999,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 Pro 16ACH6 82L500KRMH',
#   'url': 'https://www.coolblue.nl/en/product/891630/lenovo-ideapad-5-pro-16ach6-82l500krmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.249,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 14ITL05 82FE015JMH',
#   'url': 'https://www.coolblue.nl/en/product/891598/lenovo-ideapad-5-14itl05-82fe015jmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.049,-</strong>},
#  {'title': 'Lenovo Legion 5 15ITH6H 82JH005MMH',
#   'url': 'https://www.coolblue.nl/en/product/882856/lenovo-legion-5-15ith6h-82jh005mmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.499,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Asus Vivobook 15 X571GT-BQ009T',
#   'url': 'https://www.coolblue.nl/en/product/879012/asus-vivobook-15-x571gt-bq009t.html',
#   'price': <strong class="sales-price__current js-sales-price-current">749,-</strong>},
#  {'title': 'Microsoft Surface Pro 8 - i5/16/256 (Platinum)',
#   'url': 'https://www.coolblue.nl/en/product/897654/microsoft-surface-pro-8-i5-16-256-platinum.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.249,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Lenovo IdeaPad 3 14ITL6 82H700JVMH',
#   'url': 'https://www.coolblue.nl/en/product/878356/lenovo-ideapad-3-14itl6-82h700jvmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">449,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 14ITL05 82FE015HMH',
#   'url': 'https://www.coolblue.nl/en/product/891595/lenovo-ideapad-5-14itl05-82fe015hmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">649,-</strong>},
#  {'title': 'Asus Vivobook Pro 14X M7400QE-KM032W',
#   'url': 'https://www.coolblue.nl/en/product/893956/asus-vivobook-pro-14x-m7400qe-km032w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.699,-</strong>},
#  {'title': 'MSI Raider GE76 Deluxe Edition 12UH-677NL',
#   'url': 'https://www.coolblue.nl/en/product/899581/msi-raider-ge76-deluxe-edition-12uh-677nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">3.999,-</strong>},
#  {'title': 'Acer Aspire 5 A515-45-R41H',
#   'url': 'https://www.coolblue.nl/en/product/882442/acer-aspire-5-a515-45-r41h.html',
#   'price': <strong class="sales-price__current js-sales-price-current">579,-</strong>},
#  {'title': 'Lenovo IdeaPad Flex 5 14ALC05 82HU00D1MH',
#   'url': 'https://www.coolblue.nl/en/product/878298/lenovo-ideapad-flex-5-14alc05-82hu00d1mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">628,95</strong>},
#  {'title': 'Lenovo IdeaPad 3 14ITL6 82H700JUMH',
#   'url': 'https://www.coolblue.nl/en/product/878304/lenovo-ideapad-3-14itl6-82h700jumh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">449,-</strong>},
#  {'title': 'HP ENVY x360 15-eu0988nd',
#   'url': 'https://www.coolblue.nl/en/product/890664/hp-envy-x360-15-eu0988nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.049,-</strong>},
#  {'title': 'HP 14s-fq1961nd',
#   'url': 'https://www.coolblue.nl/en/product/891953/hp-14s-fq1961nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">659,-</strong>},
#  {'title': 'Asus Expertbook B1500CEAE-BQ1884R',
#   'url': 'https://www.coolblue.nl/en/product/890743/asus-expertbook-b1500ceae-bq1884r.html',
#   'price': <strong class="sales-price__current js-sales-price-current">839,-</strong>},
#  {'title': 'HP 14s-dq4960nd',
#   'url': 'https://www.coolblue.nl/en/product/891949/hp-14s-dq4960nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">649,-</strong>},
#  {'title': 'HP OMEN 16-b0970nd',
#   'url': 'https://www.coolblue.nl/en/product/883969/hp-omen-16-b0970nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.699,-</strong>},
#  {'title': 'Asus TUF Gaming A15 FA507RC-HN056W',
#   'url': 'https://www.coolblue.nl/en/product/898548/asus-tuf-gaming-a15-fa507rc-hn056w.html',
# ...
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Asus Vivobook Pro 15 K3500PH-L1393W',
#   'url': 'https://www.coolblue.nl/en/product/903686/asus-vivobook-pro-15-k3500ph-l1393w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.199,-</strong>},
#  {'title': 'HP 17-cn0971nd',
#   'url': 'https://www.coolblue.nl/en/product/891407/hp-17-cn0971nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">949,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Asus Vivobook 15 OLED M513UA-L1427W',
#   'url': 'https://www.coolblue.nl/en/product/893946/asus-vivobook-15-oled-m513ua-l1427w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">949,-</strong>},
#  {'title': 'Acer Nitro 5 AN517-54-73TD',
#   'url': 'https://www.coolblue.nl/en/product/895443/acer-nitro-5-an517-54-73td.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.499,-</strong>},
#  {'title': 'Samsung Galaxy Book2 360 13 NP730QED-KA1NL',
#   'url': 'https://www.coolblue.nl/en/product/901780/samsung-galaxy-book2-360-13-np730qed-ka1nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.099,-</strong>},
#  {'title': 'Microsoft Surface Laptop 4 13.5 inches i7 - 16GB - 512GB Platinum (W11)',
#   'url': 'https://www.coolblue.nl/en/product/902122/microsoft-surface-laptop-4-13-5-inches-i7-16gb-512gb-platinum-w11.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.449,-</strong>},
#  {'title': 'Microsoft Surface Pro X - SQ2 - 16GB - 256GB Black',
#   'url': 'https://www.coolblue.nl/en/product/869656/microsoft-surface-pro-x-sq2-16gb-256gb-black.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.049,-</strong>},
#  {'title': 'Acer Enduro Urban N3 EUN314-51W-57NG',
#   'url': 'https://www.coolblue.nl/en/product/899151/acer-enduro-urban-n3-eun314-51w-57ng.html',
#   'price': <strong class="sales-price__current js-sales-price-current">999,-</strong>},
#  {'title': 'MSI Modern 15 A11M-819NL',
#   'url': 'https://www.coolblue.nl/en/product/892838/msi-modern-15-a11m-819nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">699,-</strong>},
#  {'title': 'Apple MacBook Air (2020) MGNA3N/A Silver',
#   'url': 'https://www.coolblue.nl/en/product/873129/apple-macbook-air-2020-mgna3n-a-silver.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.249,-</strong>},
#  {'title': 'Lenovo IdeaPad Flex 3 Chromebook 11IGL05 82BB0012MH',
#   'url': 'https://www.coolblue.nl/en/product/860579/lenovo-ideapad-flex-3-chromebook-11igl05-82bb0012mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">279,-</strong>},
#  {'title': 'Medion Erazer Beast X25 MD62182',
#   'url': 'https://www.coolblue.nl/en/product/877278/medion-erazer-beast-x25-md62182.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.999,-</strong>},
#  {'title': 'MSI GS76 Stealth 11UG-477NL',
#   'url': 'https://www.coolblue.nl/en/product/889897/msi-gs76-stealth-11ug-477nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.639,-</strong>},
#  {'title': 'Acer Predator Triton 500 SE PT516-51s-7990',
#   'url': 'https://www.coolblue.nl/en/product/900573/acer-predator-triton-500-se-pt516-51s-7990.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.999,-</strong>},
#  {'title': 'HP Pavilion Aero 13-be0971nd',
#   'url': 'https://www.coolblue.nl/en/product/891938/hp-pavilion-aero-13-be0971nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">949,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 14ITL05 82FE00PVMH',
#   'url': 'https://www.coolblue.nl/en/product/878305/lenovo-ideapad-5-14itl05-82fe00pvmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">649,-</strong>},
#  {'title': 'Lenovo IdeaPad 3 Chromebook 14M836 82KN000PMH',
#   'url': 'https://www.coolblue.nl/en/product/885809/lenovo-ideapad-3-chromebook-14m836-82kn000pmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">299,-</strong>},
#  {'title': 'HP 15s-fq4970nd',
#   'url': 'https://www.coolblue.nl/en/product/891963/hp-15s-fq4970nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">829,-</strong>},
#  {'title': 'Asus Vivobook Flip 14 TP1400KA-EC002WS',
#   'url': 'https://www.coolblue.nl/en/product/898518/asus-vivobook-flip-14-tp1400ka-ec002ws.html',
#   'price': <strong class="sales-price__current js-sales-price-current">429,-</strong>},
#  {'title': 'HP 15s-fq0901nd',
#   'url': 'https://www.coolblue.nl/en/product/892686/hp-15s-fq0901nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">369,-</strong>},
#  {'title': 'Acer Swift 3 SF314-511-5622',
#   'url': 'https://www.coolblue.nl/en/product/882456/acer-swift-3-sf314-511-5622.html',
#   'price': <strong class="sales-price__current js-sales-price-current">779,-</strong>},
#  {'title': 'Acer Aspire 3 A317-52-34HE',
#   'url': 'https://www.coolblue.nl/en/product/863792/acer-aspire-3-a317-52-34he.html',
#   'price': <strong class="sales-price__current js-sales-price-current">629,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Apple MacBook Pro 13 inches (2020) MYD92N/A Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/873119/apple-macbook-pro-13-inches-2020-myd92n-a-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.499,-</strong>},
#  {'title': 'Medion Erazer Crawler E25 MD62301',
#   'url': 'https://www.coolblue.nl/en/product/897749/medion-erazer-crawler-e25-md62301.html',
#   'price': <strong class="sales-price__current js-sales-price-current">999,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Lenovo IdeaPad Gaming 3 15IMH05 81Y40198MH',
#   'url': 'https://www.coolblue.nl/en/product/879997/lenovo-ideapad-gaming-3-15imh05-81y40198mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">799,-</strong>},
#  {'title': 'Medion Erazer Defender P10 MD62237',
#   'url': 'https://www.coolblue.nl/en/product/877279/medion-erazer-defender-p10-md62237.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.099,-</strong>},
#  {'title': 'Asus X515EA-EJ910W',
#   'url': 'https://www.coolblue.nl/en/product/893940/asus-x515ea-ej910w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">529,-</strong>},
#  {'title': 'Lenovo IdeaPad 3 15IIL05 81WE00FJMH',
#   'url': 'https://www.coolblue.nl/en/product/860850/lenovo-ideapad-3-15iil05-81we00fjmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">549,-</strong>},
#  {'title': 'Acer Spin 3 SP314-54N-57VR',
#   'url': 'https://www.coolblue.nl/en/product/857080/acer-spin-3-sp314-54n-57vr.html',
#   'price': <strong class="sales-price__current js-sales-price-current">829,-</strong>},
#  {'title': 'Asus Vivobook Slate 13 OLED T3300KA-LQ072W',
#   'url': 'https://www.coolblue.nl/en/product/898533/asus-vivobook-slate-13-oled-t3300ka-lq072w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">699,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 14ARE05 81YM007EMH',
#   'url': 'https://www.coolblue.nl/en/product/860795/lenovo-ideapad-5-14are05-81ym007emh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">719,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 15ALC05 82LN00NJMH',
#   'url': 'https://www.coolblue.nl/en/product/891618/lenovo-ideapad-5-15alc05-82ln00njmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">779,-</strong>},
#  {'title': 'Asus Chromebook CX9400CEA-KC0015',
#   'url': 'https://www.coolblue.nl/en/product/886182/asus-chromebook-cx9400cea-kc0015.html',
#   'price': <strong class="sales-price__current js-sales-price-current">899,-</strong>},
#  {'title': 'HP OMEN 15-ek1950nd',
#   'url': 'https://www.coolblue.nl/en/product/876295/hp-omen-15-ek1950nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.899,-</strong>},
#  {'title': 'Lenovo ThinkPad P15 G2 - 20YQ000YMH',
#   'url': 'https://www.coolblue.nl/en/product/889613/lenovo-thinkpad-p15-g2-20yq000ymh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.799,-</strong>},
#  {'title': 'Asus ROG Zephyrus G14 GA401QM-K2341T',
#   'url': 'https://www.coolblue.nl/en/product/892682/asus-rog-zephyrus-g14-ga401qm-k2341t.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.899,-</strong>},
#  {'title': 'MSI Modern 15 A11M-821NL',
#   'url': 'https://www.coolblue.nl/en/product/892839/msi-modern-15-a11m-821nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">749,-</strong>},
#  {'title': 'Asus Zenbook 14 UM425QA-KI163W',
#   'url': 'https://www.coolblue.nl/en/product/898535/asus-zenbook-14-um425qa-ki163w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">899,-</strong>},
#  {'title': 'HP 14s-dq2930nd',
#   'url': 'https://www.coolblue.nl/en/product/873226/hp-14s-dq2930nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">502,95</strong>},
#  {'title': 'MSI Modern 15 A11ML-448NL',
#   'url': 'https://www.coolblue.nl/en/product/882303/msi-modern-15-a11ml-448nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">586,-</strong>},
#  {'title': 'Asus TUF Gaming F15 FX506LH-HN004W',
#   'url': 'https://www.coolblue.nl/en/product/898552/asus-tuf-gaming-f15-fx506lh-hn004w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">849,-</strong>},
#  {'title': 'Apple MacBook Pro 16 inches (2021) M1 Pro (10-core CPU/16-core GPU) 32GB/1TB Space Gray',
#   'url': 'https://www.coolblue.nl/en/product/894444/apple-macbook-pro-16-inches-2021-m1-pro-10-core-cpu-16-core-gpu-32gb-1tb-space-gray.html',
#   'price': <strong class="sales-price__current js-sales-price-current">3.439,-</strong>},
#  {'title': 'Asus Vivobook 14 K3400PA-KP115W',
#   'url': 'https://www.coolblue.nl/en/product/893941/asus-vivobook-14-k3400pa-kp115w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">899,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 14ALC05 82LM009UMH',
#   'url': 'https://www.coolblue.nl/en/product/878362/lenovo-ideapad-5-14alc05-82lm009umh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">649,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Dynabook Satellite Pro C50-J-10S',
#   'url': 'https://www.coolblue.nl/en/product/901874/dynabook-satellite-pro-c50-j-10s.html',
#   'price': <strong class="sales-price__current js-sales-price-current">729,-</strong>},
#  {'title': 'Acer Swift 3 SF316-51-771D',
#   'url': 'https://www.coolblue.nl/en/product/899923/acer-swift-3-sf316-51-771d.html',
#   'price': <strong class="sales-price__current js-sales-price-current">999,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None},
#  {'title': 'Lenovo IdeaPad 5 Pro 16ACH6 82L500KPMH',
#   'url': 'https://www.coolblue.nl/en/product/891628/lenovo-ideapad-5-pro-16ach6-82l500kpmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">999,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 Pro 14ACN6 82L700GLMH',
#   'url': 'https://www.coolblue.nl/en/product/891605/lenovo-ideapad-5-pro-14acn6-82l700glmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">849,-</strong>},
#  {'title': 'Asus VivoBook S14 S433EA-AM214T',
#   'url': 'https://www.coolblue.nl/en/product/874319/asus-vivobook-s14-s433ea-am214t.html',
#   'price': <strong class="sales-price__current js-sales-price-current">729,-</strong>},
#  {'title': 'Acer Spin 1 SP111-33-C2W8',
#   'url': 'https://www.coolblue.nl/en/product/896205/acer-spin-1-sp111-33-c2w8.html',
#   'price': <strong class="sales-price__current js-sales-price-current">349,-</strong>},
#  {'title': 'HP 15s-fq3910nd',
#   'url': 'https://www.coolblue.nl/en/product/891960/hp-15s-fq3910nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">419,-</strong>},
#  {'title': 'Microsoft Surface Laptop 4 13.5 inches R5se - 8GB - 256GB Platinum',
#   'url': 'https://www.coolblue.nl/en/product/877629/microsoft-surface-laptop-4-13-5-inches-r5se-8gb-256gb-platinum.html',
#   'price': <strong class="sales-price__current js-sales-price-current">899,-</strong>},
#  {'title': 'Asus Vivobook 15 OLED M513UA-L1376W',
#   'url': 'https://www.coolblue.nl/en/product/893945/asus-vivobook-15-oled-m513ua-l1376w.html',
#   'price': <strong class="sales-price__current js-sales-price-current">849,-</strong>},
#  {'title': 'Lenovo IdeaPad 5 14ITL05 82FE0158MH',
#   'url': 'https://www.coolblue.nl/en/product/893988/lenovo-ideapad-5-14itl05-82fe0158mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">849,-</strong>},
#  {'title': 'Medion E4251B-N4020-4-128',
#   'url': 'https://www.coolblue.nl/en/product/899607/medion-e4251b-n4020-4-128.html',
#   'price': <strong class="sales-price__current js-sales-price-current">299,-</strong>},
#  {'title': 'Lenovo IdeaPad Flex 3 11IGL05 82B2006NMH',
#   'url': 'https://www.coolblue.nl/en/product/891586/lenovo-ideapad-flex-3-11igl05-82b2006nmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">399,-</strong>},
#  {'title': 'Lenovo IdeaPad 3 Chromebook 14M836 82KN000XMH',
#   'url': 'https://www.coolblue.nl/en/product/876283/lenovo-ideapad-3-chromebook-14m836-82kn000xmh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">269,-</strong>},
#  {'title': 'Lenovo IdeaPad 3 14IGL05 81WH0073MH',
#   'url': 'https://www.coolblue.nl/en/product/891588/lenovo-ideapad-3-14igl05-81wh0073mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">369,-</strong>},
#  {'title': 'ConceptD 7 Ezel CC715-71P-73YE',
#   'url': 'https://www.coolblue.nl/en/product/865770/conceptd-7-ezel-cc715-71p-73ye.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.699,-</strong>},
#  {'title': 'HP OMEN 16-c0975nd',
#   'url': 'https://www.coolblue.nl/en/product/883953/hp-omen-16-c0975nd.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.849,-</strong>},
#  {'title': 'ConceptD 3 Pro CN315-72P-7962',
#   'url': 'https://www.coolblue.nl/en/product/879621/conceptd-3-pro-cn315-72p-7962.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.549,-</strong>},
#  {'title': 'Medion Erazer Defender MD62305',
#   'url': 'https://www.coolblue.nl/en/product/889013/medion-erazer-defender-md62305.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.499,-</strong>},
#  {'title': 'Lenovo ThinkPad P17 G2 - 20YU0028MH',
#   'url': 'https://www.coolblue.nl/en/product/889612/lenovo-thinkpad-p17-g2-20yu0028mh.html',
#   'price': <strong class="sales-price__current js-sales-price-current">2.449,-</strong>},
#  {'title': 'HP EliteBook 850 G8 - 2Y2S2EA',
#   'url': 'https://www.coolblue.nl/en/product/889653/hp-elitebook-850-g8-2y2s2ea.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.659,-</strong>},
#  {'title': 'HP EliteBook 830 G8 - 35T66EA',
#   'url': 'https://www.coolblue.nl/en/product/889656/hp-elitebook-830-g8-35t66ea.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.489,-</strong>},
#  {'title': 'MSI Summit E14 Flip Evo A12MT-019NL',
#   'url': 'https://www.coolblue.nl/en/product/900882/msi-summit-e14-flip-evo-a12mt-019nl.html',
#   'price': <strong class="sales-price__current js-sales-price-current">1.749,-</strong>},
#  {'title': '',
#   'url': 'https://www.coolblue.nlhttps://www.coolblue.nl/en/c/app.html',
#   'price': None}]

# %%
print("The number of all laptops is " +str(len(information_list_al)))
# Out:
# The number of all laptops is 480

# %% [markdown]
# # <span style="color:blue">3. Saving the scraped data in csv files</span>

# %% [markdown]
# ### 3.1 For Coolblues Choice

# %%
with open("coolblues-choice.csv", "w", encoding = 'utf-8') as csv_file: # <<- this is the line with the "flag"l see exercises below
    writer = csv.writer(csv_file, delimiter = ";")
    writer.writerow(["title", "url", "price"])
    for cc_info in information_list_cc: # here we reference the book_descriptions list - make sure it's loaded otherwise you get an error! (Cell > Run All Above)
        writer.writerow([cc_info['title'], cc_info['url'], cc_info['price']])
print('done cc!')
# Out:
# done cc!

# %% [markdown]
# ### 3.1 For All Laptops

# %%
with open("all-laptops.csv", "w", encoding = 'utf-8') as csv_file: # <<- this is the line with the "flag"l see exercises below
    writer = csv.writer(csv_file, delimiter = ";")
    writer.writerow(["title", "url", "price"])
    for al_info in information_list_al: # here we reference the book_descriptions list - make sure it's loaded otherwise you get an error! (Cell > Run All Above)
        writer.writerow([al_info['title'], al_info['url'], al_info['price']])
print('done al!')
# Out:
# done al!
